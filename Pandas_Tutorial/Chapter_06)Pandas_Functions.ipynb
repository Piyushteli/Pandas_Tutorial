# %% [markdown]
# # Pandas Functions

# %%
import pandas as pd
csv_1=pd.read_csv("C:\\Users\\ADMIN\\Downloads\\Bengaluru_House_Data.csv")
csv_1
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
csv_1.index
# Out:
# RangeIndex(start=0, stop=13320, step=1)

# %%
csv_1.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
csv_1.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
csv_1.head()           #By default it gives upper 5 rows
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
csv_1.tail(3)          #By default it gives lower 5 rows
# Out:
#                   area_type   availability               location   size  \
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar  2 BHK
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar  4 BHK
# 13319  Super built-up  Area  Ready To Move           Doddathoguru  1 BHK
#
#        society total_sqft  bath  balcony  price
# 13317  Mahla T       1141   2.0      1.0   60.0
# 13318  SollyCl       4689   4.0      1.0  488.0
# 13319      NaN        550   1.0      1.0   17.0

# %% [markdown]
# # Slicing

# %%
csv_1[:6]
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
# 5  Super built-up  Area  Ready To Move                Whitefield      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00
# 5  DuenaTa       1170   2.0      1.0   38.00

# %%
csv_1[6:11]
# Out:
#                area_type   availability          location       size  society  \
# 6   Super built-up  Area         18-May  Old Airport Road      4 BHK  Jaades
# 7   Super built-up  Area  Ready To Move      Rajaji Nagar      4 BHK  Brway G
# 8   Super built-up  Area  Ready To Move      Marathahalli      3 BHK      NaN
# 9             Plot  Area  Ready To Move      Gandhi Bazar  6 Bedroom      NaN
# 10  Super built-up  Area         18-Feb        Whitefield      3 BHK      NaN
#
#    total_sqft  bath  balcony   price
# 6        2732   4.0      NaN  204.00
# 7        3300   4.0      NaN  600.00
# 8        1310   3.0      1.0   63.25
# 9        1020   6.0      NaN  370.00
# 10       1800   2.0      2.0   70.00

# %%
csv_1.sort_index(axis=0,ascending=False)          #according to rows
# Out:
#                   area_type   availability                  location  \
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13315        Built-up  Area  Ready To Move                Whitefield
# ...                     ...            ...                       ...
# 4      Super built-up  Area  Ready To Move                  Kothanur
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
#
#             size  society total_sqft  bath  balcony   price
# 13319      1 BHK      NaN        550   1.0      1.0   17.00
# ...

# %% [markdown]
# # To change the Data

# %%
csv_1.loc[0,"area_type"]="Plot Area"
csv_1
# Out:
#                   area_type   availability                  location  \
# 0                 Plot Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %% [markdown]
# # To get the values using loc function

# %%
csv_1.loc[[1,4],["location","size"]]
# Out:
#            location       size
# 1  Chikka Tirupathi  4 Bedroom
# 4          Kothanur      2 BHK

# %%
csv_1.loc[:,["location","size"]]
# Out:
#                        location       size
# 0      Electronic City Phase II      2 BHK
# 1              Chikka Tirupathi  4 Bedroom
# 2                   Uttarahalli      3 BHK
# 3            Lingadheeranahalli      3 BHK
# 4                      Kothanur      2 BHK
# ...                         ...        ...
# 13315                Whitefield  5 Bedroom
# 13316             Richards Town      4 BHK
# 13317     Raja Rajeshwari Nagar      2 BHK
# 13318           Padmanabhanagar      4 BHK
# 13319              Doddathoguru      1 BHK
#
# [13320 rows x 2 columns]

# %%
csv_1.loc[[1,4],:]
# Out:
#               area_type   availability          location       size  society  \
# 1            Plot  Area  Ready To Move  Chikka Tirupathi  4 Bedroom  Theanmp
# 4  Super built-up  Area  Ready To Move          Kothanur      2 BHK      NaN
#
#   total_sqft  bath  balcony  price
# 1       2600   5.0      3.0  120.0
# 4       1200   2.0      1.0   51.0

# %%
csv_1.iloc[0,2]      #iloc[index_number(row),index_number(column)]
# Out:
# 'Electronic City Phase II'

# %% [markdown]
# # To delete the Particular column from data

# %%
csv_1.drop("availability",axis=1)      #axis=0 for rows  , #axis=1 for column
# Out:
#                   area_type                  location       size  society  \
# 0                 Plot Area  Electronic City Phase II      2 BHK  Coomee
# 1                Plot  Area          Chikka Tirupathi  4 Bedroom  Theanmp
# 2            Built-up  Area               Uttarahalli      3 BHK      NaN
# 3      Super built-up  Area        Lingadheeranahalli      3 BHK  Soiewre
# 4      Super built-up  Area                  Kothanur      2 BHK      NaN
# ...                     ...                       ...        ...      ...
# 13315        Built-up  Area                Whitefield  5 Bedroom  ArsiaEx
# 13316  Super built-up  Area             Richards Town      4 BHK      NaN
# 13317        Built-up  Area     Raja Rajeshwari Nagar      2 BHK  Mahla T
# 13318  Super built-up  Area           Padmanabhanagar      4 BHK  SollyCl
# 13319  Super built-up  Area              Doddathoguru      1 BHK      NaN
#
#       total_sqft  bath  balcony   price
# 0           1056   2.0      1.0   39.07
# ...

# %% [markdown]
# # To delete the Particular row from data

# %%
csv_1.drop(0,axis=0)
# Out:
#                   area_type   availability               location       size  \
# 1                Plot  Area  Ready To Move       Chikka Tirupathi  4 Bedroom
# 2            Built-up  Area  Ready To Move            Uttarahalli      3 BHK
# 3      Super built-up  Area  Ready To Move     Lingadheeranahalli      3 BHK
# 4      Super built-up  Area  Ready To Move               Kothanur      2 BHK
# 5      Super built-up  Area  Ready To Move             Whitefield      2 BHK
# ...                     ...            ...                    ...        ...
# 13315        Built-up  Area  Ready To Move             Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move          Richards Town      4 BHK
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar      4 BHK
# 13319  Super built-up  Area  Ready To Move           Doddathoguru      1 BHK
#
# ...
