# %% [markdown]
# # Read CSV files

# %%
import pandas as pd
csv_1=pd.read_csv("C:\\Users\\ADMIN\\Downloads\\Bengaluru_House_Data.csv")
csv_1
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %% [markdown]
# # To get the single row from the data

# %%
import pandas as pd
csv_2=pd.read_csv(r"C:\Users\ADMIN\Downloads\Bengaluru_House_Data.csv",nrows=3)
csv_2
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
#
#    society  total_sqft  bath  balcony   price
# 0  Coomee         1056     2        1   39.07
# 1  Theanmp        2600     5        3  120.00
# 2      NaN        1440     2        3   62.00

# %% [markdown]
# # To get the single column from the data

# %%
import pandas as pd
csv_3=pd.read_csv(r"C:\Users\ADMIN\Downloads\Bengaluru_House_Data.csv",usecols=["location","size"])   #get using the column name 
csv_3
# Out:
#                        location       size
# 0      Electronic City Phase II      2 BHK
# 1              Chikka Tirupathi  4 Bedroom
# 2                   Uttarahalli      3 BHK
# 3            Lingadheeranahalli      3 BHK
# 4                      Kothanur      2 BHK
# ...                         ...        ...
# 13315                Whitefield  5 Bedroom
# 13316             Richards Town      4 BHK
# 13317     Raja Rajeshwari Nagar      2 BHK
# 13318           Padmanabhanagar      4 BHK
# 13319              Doddathoguru      1 BHK
#
# [13320 rows x 2 columns]

# %%
import pandas as pd
csv_4=pd.read_csv(r"C:\Users\ADMIN\Downloads\Bengaluru_House_Data.csv",usecols=[4,5,6])   #get using column indexes
csv_4
# Out:
#        society total_sqft  bath
# 0      Coomee        1056   2.0
# 1      Theanmp       2600   5.0
# 2          NaN       1440   2.0
# 3      Soiewre       1521   3.0
# 4          NaN       1200   2.0
# ...        ...        ...   ...
# 13315  ArsiaEx       3453   4.0
# 13316      NaN       3600   5.0
# 13317  Mahla T       1141   2.0
# 13318  SollyCl       4689   4.0
# 13319      NaN        550   1.0
#
# [13320 rows x 3 columns]

# %%
import pandas as pd
csv_5=pd.read_csv(r"C:\Users\ADMIN\Downloads\Bengaluru_House_Data.csv",skiprows=[2,4])
csv_5
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1            Built-up  Area  Ready To Move               Uttarahalli
# 2      Super built-up  Area  Ready To Move                  Kothanur
# 3      Super built-up  Area  Ready To Move                Whitefield
# 4      Super built-up  Area         18-May          Old Airport Road
# ...                     ...            ...                       ...
# 13313        Built-up  Area  Ready To Move                Whitefield
# 13314  Super built-up  Area  Ready To Move             Richards Town
# 13315        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13316  Super built-up  Area         18-Jun           Padmanabhanagar
# 13317  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %% [markdown]
# # Change the heading

# %%
import pandas as pd
csv_6=pd.read_csv(r"C:\Users\ADMIN\Downloads\Bengaluru_House_Data.csv",names=["Area_type","Availability","Location","Size","Society","Total_sqft","Bath","Balcony","Price"])
csv_6
# Out:
#                   Area_type   Availability                  Location  \
# 0                 area_type   availability                  location
# 1      Super built-up  Area         19-Dec  Electronic City Phase II
# 2                Plot  Area  Ready To Move          Chikka Tirupathi
# 3            Built-up  Area  Ready To Move               Uttarahalli
# 4      Super built-up  Area  Ready To Move        Lingadheeranahalli
# ...                     ...            ...                       ...
# 13316        Built-up  Area  Ready To Move                Whitefield
# 13317  Super built-up  Area  Ready To Move             Richards Town
# 13318        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13319  Super built-up  Area         18-Jun           Padmanabhanagar
# 13320  Super built-up  Area  Ready To Move              Doddathoguru
#
#             Size  Society  Total_sqft  Bath  Balcony  Price
# 0           size  society  total_sqft  bath  balcony  price
# ...

# %% [markdown]
# # Prefix Method

# %%
import pandas as pd
csv_7=pd.read_csv(r"C:\Users\ADMIN\Downloads\Bengaluru_House_Data.csv",header=None,prefix="col1")
csv_7
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3484\881285777.py:2: FutureWarning: The prefix argument has been deprecated and will be removed in a future version. Use a list comprehension on the column names in the future.
#
#
#   csv_7=pd.read_csv(r"C:\Users\ADMIN\Downloads\Bengaluru_House_Data.csv",header=None,prefix="col1")
#                       col10          col11                     col12  \
# 0                 area_type   availability                  location
# 1      Super built-up  Area         19-Dec  Electronic City Phase II
# 2                Plot  Area  Ready To Move          Chikka Tirupathi
# 3            Built-up  Area  Ready To Move               Uttarahalli
# 4      Super built-up  Area  Ready To Move        Lingadheeranahalli
# ...                     ...            ...                       ...
# 13316        Built-up  Area  Ready To Move                Whitefield
# 13317  Super built-up  Area  Ready To Move             Richards Town
# ...

# %% [markdown]
# # To change the Datatype

# %%
import pandas as pd
csv_8=pd.read_csv("C:\\Users\\ADMIN\\Downloads\\Bengaluru_House_Data.csv",dtype={"Balcony":"int"})
csv_8
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...
